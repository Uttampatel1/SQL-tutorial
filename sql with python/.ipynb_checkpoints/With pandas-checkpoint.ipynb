# %%
import pandas as pd
import sqlite3
import sqlalchemy

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\utamp\anaconda3\lib\site-packages (1.4.32)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\utamp\anaconda3\lib\site-packages (from sqlalchemy) (1.1.1)

# %%
engine = sqlalchemy.create_engine('sqlite:///OurDataBase.db')

# %%
pd.read_sql('employees',engine)
# Out:
#      name   sarname     salary
# 0   uttam  pipaliya  1000000.0
# 1  mitali  navadiya  1000000.0

# %%
df1 = pd.DataFrame([{'name':'ayush','sarname':'pipaliya','salary':356455}])

# %%
df1
# Out:
#     name   surname    salary
# 0  ayush  pipaliya  43543543

# %%
df1.to_sql('employees',engine,if_exists='append',index=False)
# Out:
# 1

# %%
pd.read_sql('employees',engine)
# Out:
#      name   sarname     salary
# 0   uttam  pipaliya  1000000.0
# 1  mitali  navadiya  1000000.0
# 2   ayush  pipaliya   356455.0

# %%
import yfinance as yf
df = yf.download('GME',start='2021-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-12-31   19.250000   19.799999   18.799999   18.840000   18.840000
# 2021-01-04   19.000000   19.100000   17.150000   17.250000   17.250000
# 2021-01-05   17.350000   18.080000   17.230000   17.370001   17.370001
# 2021-01-06   17.340000   18.980000   17.330000   18.360001   18.360001
# 2021-01-07   18.469999   19.450001   18.020000   18.080000   18.080000
# ...                ...         ...         ...         ...         ...
# 2022-06-02  119.000000  136.500000  115.559998  134.000000  134.000000
# 2022-06-03  130.000000  138.100006  124.230003  133.699997  133.699997
# 2022-06-06  135.300003  136.100006  127.050003  128.100006  128.100006
# 2022-06-07  130.000000  149.889999  126.330002  146.500000  146.500000
# 2022-06-08  141.389999  152.999893  138.400101  144.759995  144.759995
#
#               Volume
# Date
# 2020-12-31   6922700
# 2021-01-04  10022500
# 2021-01-05   4961500
# 2021-01-06   6056200
# 2021-01-07   6129300
# ...              ...
# 2022-06-02   6979700
# 2022-06-03   4550500
# 2022-06-06   2383200
# 2022-06-07   6230600
# 2022-06-08   3946118
#
# [362 rows x 6 columns]

# %%
df.to_sql('GME',engine)
# Out:
# 362

# %%
pd.read_sql('GME',engine)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2020-12-31   19.250000   19.799999   18.799999   18.840000   18.840000
# 1   2021-01-04   19.000000   19.100000   17.150000   17.250000   17.250000
# 2   2021-01-05   17.350000   18.080000   17.230000   17.370001   17.370001
# 3   2021-01-06   17.340000   18.980000   17.330000   18.360001   18.360001
# 4   2021-01-07   18.469999   19.450001   18.020000   18.080000   18.080000
# ..         ...         ...         ...         ...         ...         ...
# 357 2022-06-02  119.000000  136.500000  115.559998  134.000000  134.000000
# 358 2022-06-03  130.000000  138.100006  124.230003  133.699997  133.699997
# 359 2022-06-06  135.300003  136.100006  127.050003  128.100006  128.100006
# 360 2022-06-07  130.000000  149.889999  126.330002  146.500000  146.500000
# 361 2022-06-08  141.389999  152.999893  138.400101  144.759995  144.759995
#
#        Volume
# 0     6922700
# 1    10022500
# 2     4961500
# 3     6056200
# 4     6129300
# ..        ...
# 357   6979700
# 358   4550500
# 359   2383200
# 360   6230600
# 361   3946118
#
# [362 rows x 7 columns]
